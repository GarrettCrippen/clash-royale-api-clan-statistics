# %% [raw]
# Lab2A: API - Clash Royale

# %%
import requests
import json

#key generated using server i.p.
key = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..-SpiXnky9r3ekdbomuU_zTh_QcXJKRfiNiEqKAT2ykrpUCH8OgJGMcj6H4gXJvRtJ_p4fSGA5W5HDUZQ5BCP2w'
base_url = 'https://api.clashroyale.com/v1'

#UNICODE replace hashtag('#') with ('%23')
player =''
clan = "%238UU88QU0"
end_point = '/clans/%s'%clan+'/riverracelog'

response = requests.get(base_url+end_point,headers = {"Accept":"application/json","Authorization":"Bearer %s"%key},params={'limit':5})

# %%
import pandas as pd
from pandas.io.json import json_normalize

data=response.json()
rows = []

for element in data['items']:
    for standing in element['standings']:
        if(standing['clan']['name']=='royale w cheese'):
           # print(json.dumps(standing['clan']['participants'],indent=2))
            for players in standing['clan']['participants']:
                name = players['name']
                decks_used = players['decksUsed']
                fame = players['fame']
                rows.append([name,decks_used,fame])

df = pd.DataFrame(rows)
df=df.rename(columns={0:'name',1:'decks_used',2:'fame'})
df=df.set_index('name')

df2 = df.groupby('name').mean().sort_values('fame',ascending=False)

df2.head(50)
# Out:
#                  decks_used         fame
# name
# Gilbertothecrip   27.800000  2670.000000
# Sir Tough Guy     27.800000  2590.000000
# silky024          25.600000  2530.000000
# akbar             26.200000  2520.000000
# IronBlood         27.200000  2460.000000
# antintin          26.200000  2420.000000
# KeeperOfTheFire   25.600000  2410.000000
# nate              27.200000  2410.000000
# Royale W Cheese   28.000000  2320.000000
# OVI888            22.400000  2310.000000
# bear’s end        16.400000  2270.000000
# JEdwardRomeoK     28.000000  2240.000000
# DontTazeMeBro     20.600000  2240.000000
# KING AMAROQ       23.750000  2237.500000
# boom              23.200000  2165.000000
# AK47              21.600000  1990.000000
# schno             14.400000  1970.000000
# mbhill            21.400000  1915.000000
# Uncle Dan         21.600000  1890.000000
# Coach             15.600000  1860.000000
# SirVladimir       12.400000  1750.000000
# 无敌骚年              17.200000  1720.000000
# ...
